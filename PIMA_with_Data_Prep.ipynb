# %% [markdown]
# <a href="https://colab.research.google.com/github/intandeay/BangkitAssigment6/blob/master/PIMA_with_Data_Prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2> Import libraries

# %%
# %tensorflow_version 2.x

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow import feature_column
from tensorflow.keras import layers

# %% [markdown]
# <h2> Read The Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/adindariztia/Bangkit_DiabetesPredictionML/master/diabetes.csv')

# %% [markdown]
# # Preliminary Exploration with Dataset

# %% [markdown]
# First, let's see how many rows and columns in the dataset

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# Next, see the first rows of the dataset

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# There are 8 feature columns and 1 outcome.
#
# It's also good to know the distribution of each columns. So, let's see that by describe function.

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# Since this is a binary-output dataset, let's check whether the output is balanced or not.

# %%
print ("{0:.0%}".format(df.Outcome.mean()))
# Out:
# 35%

# %% [markdown]
# This dataset is not a balanced one.

# %% [markdown]
# It looks like there are some missing values replaced by "0" in this dataset. The minimum for some variables does not make sense if it is 0. Let's check the percentage of zeros for each columns.

# %%
print("Percentage of Missing Values in each Colume")
for col in df.columns[:-1]:
    print (col + " {0:.0%}".format(df[df[col] == 0].shape[0]/df.shape[0]))
# Out:
# Percentage of Missing Values in each Colume
# Pregnancies 14%
# Glucose 1%
# BloodPressure 5%
# SkinThickness 30%
# Insulin 49%
# BMI 1%
# DiabetesPedigreeFunction 0%
# Age 0%

# %%
sns.boxplot(data=df, orient='h')

# %%
print("Skewness original")
for col in df.columns:
    print(col, df[col].skew())
# Out:
# Skewness original
# Pregnancies 0.9016739791518588
# Glucose 0.17375350179188992
# BloodPressure -1.8436079833551302
# SkinThickness 0.10937249648187608
# Insulin 2.272250858431574
# BMI -0.42898158845356543
# DiabetesPedigreeFunction 1.919911066307204
# Age 1.1295967011444805
# Outcome 0.635016643444986

# %%
print("Outliers for original")
for col in df.columns[:-1]:
    q1 = df[col].quantile(0.25) 
    q3 = df[col].quantile(0.75)
    IQR = q3 - q1
    tot = sum((df[col] < q1 - 1.5 * IQR) | (df[col] > q3 + 1.5 * IQR))
    print(col, tot)
# Out:
# Outliers for original
# Pregnancies 4
# Glucose 5
# BloodPressure 45
# SkinThickness 1
# Insulin 34
# BMI 19
# DiabetesPedigreeFunction 29
# Age 9

# %%
corr = df.corr()
sns.heatmap(corr, annot = True)

# %% [markdown]
# Let's substitute the zero values in some columns with median/mean by target.

# %%
df_new = df.copy()
cols_to_change = ['BMI', 'Insulin', 'SkinThickness', 'BloodPressure', 'Glucose']

for col in cols_to_change:
    mean_0 = np.mean(df.loc[(df.Outcome == 0) & (df[col] != 0) , col])
    median_0 = np.median(df.loc[(df.Outcome == 0) & (df[col] != 0), col])
    #mode_0 = statistics.mode(df.loc[(df.Outcome == 0) & (df[col] != 0), col])
    print(col)
    print("Label = 0")
    print("mean: ", mean_0, "median: ", median_0)
    mean_1 = np.mean(df.loc[(df.Outcome == 1) & (df[col] != 0), col])
    median_1 = np.median(df.loc[(df.Outcome == 1) & (df[col] != 0), col])
    #mode_1 = statistics.mode(df.loc[(df.Outcome == 1) & (df[col] != 0), col])
    print("Label = 1")
    print("mean: ", mean_1, "median: ", median_1)
    print("\n")

    # Replacing Insulin with median, since median and mean is far different
    if col == 'Insulin':
        df_new.loc[(df_new[col] == 0) & (df_new['Outcome'] == 0), col] = median_0
        df_new.loc[(df_new[col] == 0) & (df_new['Outcome'] == 1), col] = median_1
    else:
        df_new.loc[(df_new[col] == 0) & (df_new['Outcome'] == 0), col] = mean_0
        df_new.loc[(df_new[col] == 0) & (df_new['Outcome'] == 1), col] = mean_1
# Out:
# BMI
# Label = 0
# mean:  30.85967413441951 median:  30.1
# Label = 1
# mean:  35.40676691729318 median:  34.3
#
#
# Insulin
# Label = 0
# mean:  130.28787878787878 median:  102.5
# Label = 1
# mean:  206.84615384615384 median:  169.5
#
#
# SkinThickness
# Label = 0
# mean:  27.235457063711912 median:  27.0
# Label = 1
# mean:  33.0 median:  32.0
#
#
# BloodPressure
# Label = 0
# mean:  70.87733887733887 median:  70.0
# Label = 1
# mean:  75.32142857142857 median:  74.5
#
#
# Glucose
# Label = 0
# mean:  110.64386317907444 median:  107.0
# Label = 1
# mean:  142.31954887218046 median:  140.0

# %%
print("Outliers after imputation")
for col in df_new.columns:
    IQR = df_new[col].quantile(0.75) - df_new[col].quantile(0.25)
    maxVal = df_new[col].quantile(0.75) + 1.5 * IQR
    minVal = df_new[col].quantile(0.25) - 1.5 * IQR

    print(col)
    print("total Outliers: ", sum((df_new[col] < minVal) | (df_new[col] > maxVal)))
# Out:
# Outliers after imputation
# Pregnancies
# total Outliers:  4
# Glucose
# total Outliers:  0
# BloodPressure
# total Outliers:  14
# SkinThickness
# total Outliers:  53
# Insulin
# total Outliers:  51
# BMI
# total Outliers:  8
# DiabetesPedigreeFunction
# total Outliers:  29
# Age
# total Outliers:  9
# Outcome
# total Outliers:  0

# %% [markdown]
# Insulin and Skin Thickness features have significant outliers. Let's cap the outliers into certain values

# %%
# Capping outliers, penalize only column with large skewness

InsulinCappedValue = df_new['Insulin'].quantile(0.85)
df_new['Insulin'] = np.where(df_new['Insulin'] > InsulinCappedValue, 
                         InsulinCappedValue, df_new['Insulin'])


SkinThicknessCappedValue = df_new['SkinThickness'].quantile(0.95)
STminval = df_new['SkinThickness'].quantile(0.05)
df_new['SkinThickness'] = np.where(df_new['SkinThickness'] > SkinThicknessCappedValue, 
                               SkinThicknessCappedValue, df_new['SkinThickness'])

# %%
print("Outliers after Data Pre-processing 1")
for col in df_new.columns:
    IQR = df_new[col].quantile(0.75) - df_new[col].quantile(0.25)
    maxVal = df_new[col].quantile(0.75) + 1.5 * IQR
    minVal = df_new[col].quantile(0.25) - 1.5 * IQR

    print(col)
    print("total Outliers: ", sum((df_new[col] < minVal) | (df_new[col] > maxVal)))
# Out:
# Outliers after Data Pre-processing 1
# Pregnancies
# total Outliers:  4
# Glucose
# total Outliers:  0
# BloodPressure
# total Outliers:  14
# SkinThickness
# total Outliers:  22
# Insulin
# total Outliers:  0
# BMI
# total Outliers:  8
# DiabetesPedigreeFunction
# total Outliers:  29
# Age
# total Outliers:  9
# Outcome
# total Outliers:  0

# %%
print("Correlation after Data Pre-processing 1")
corr = df_new.corr()
corr.loc['Outcome']
# Out:
# Correlation after Data Pre-processing 1
# Pregnancies                 0.221898
# Glucose                     0.495954
# BloodPressure               0.175087
# SkinThickness               0.322397
# Insulin                     0.601340
# BMI                         0.315271
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
print("Distribution after Data Pre-processing 1")
sns.boxplot(data=df_new, orient='h')
# Out:
# Distribution after Data Pre-processing 1

# %%
print("Skewness after Data Pre-processing 1")
for col in df_new.columns:
    print(col, df_new[col].skew())
# Out:
# Skewness after Data Pre-processing 1
# Pregnancies 0.9016739791518588
# Glucose 0.5309321048195537
# BloodPressure 0.1315143053695826
# SkinThickness -0.18154678975021607
# Insulin -0.18879274104671473
# BMI 0.6021444766566784
# DiabetesPedigreeFunction 1.919911066307204
# Age 1.1295967011444805
# Outcome 0.635016643444986

# %%
AgeIQR = df_new['Age'].quantile(0.75) - df_new['Age'].quantile(0.25)
AgeMax = df_new['Age'].quantile(0.75) + 1.5 * AgeIQR
AgeMin = df_new['Age'].quantile(0.25) - 1.5 * AgeIQR

STmaxval = df_new['SkinThickness'].quantile(0.95)
STminval = df_new['SkinThickness'].quantile(0.05) 

def replaceOutliers(x, minv, maxv):
    if (x < minv):
        return minv
    elif (x > maxv):
        return maxv
    else:
        return x

ageNew = df_new.Age.apply(lambda x: np.median(df.Age) 
                                    if (x > AgeMax + 1.5*IQR) else x)  
df_new.Age = ageNew 

# stNew = df_new.SkinThickness.apply(lambda x: replaceOutliers(x, STminval, STmaxval))
# df_new.SkinThickness = stNew

from sklearn.preprocessing import power_transform
data = df['DiabetesPedigreeFunction'].values.reshape((-1,1))
df_new['DiabetesPedigreeFunction'] = power_transform(data, method='yeo-johnson')

# %%
print("Outliers after Data pre-processing 2")
for col in df_new.columns:
    IQR = df_new[col].quantile(0.75) - df_new[col].quantile(0.25)
    maxVal = df_new[col].quantile(0.75) + 1.5 * IQR
    minVal = df_new[col].quantile(0.25) - 1.5 * IQR

    print(col)
    print("total Outliers: ", sum((df_new[col] < minVal) | (df_new[col] > maxVal)))
# Out:
# Outliers after Data pre-processing 2
# Pregnancies
# total Outliers:  4
# Glucose
# total Outliers:  0
# BloodPressure
# total Outliers:  14
# SkinThickness
# total Outliers:  22
# Insulin
# total Outliers:  0
# BMI
# total Outliers:  8
# DiabetesPedigreeFunction
# total Outliers:  0
# Age
# total Outliers:  11
# Outcome
# total Outliers:  0

# %%
print("Skewness after Data Pre-processing 2")
for col in df_new.columns:
    print(col, df_new[col].skew())
# Out:
# Skewness after Data Pre-processing 2
# Pregnancies 0.9016739791518588
# Glucose 0.5309321048195537
# BloodPressure 0.1315143053695826
# SkinThickness -0.18154678975021607
# Insulin -0.18879274104671473
# BMI 0.6021444766566784
# DiabetesPedigreeFunction 0.1423213533223871
# Age 1.0611545653580166
# Outcome 0.635016643444986

# %% [markdown]
# Let's check the distribution of each features after preparation.

# %%
sns.boxplot(data=df_new, orient='h')

# %% [markdown]
# Create Correlation Matrix to Know Correlating Features

# %%
corr = df_new.corr()
sns.heatmap(corr, annot = True)

# %%
corr.loc['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.495954
# BloodPressure               0.175087
# SkinThickness               0.322397
# Insulin                     0.601340
# BMI                         0.315271
# DiabetesPedigreeFunction    0.179711
# Age                         0.255757
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# From the correlation matrix, there are four strongest correlating variables to the outcome. We will use them for training the model.

# %%
from google.colab import files
df_new.to_csv('diabetes_dataprep.csv') 
files.download('diabetes_dataprep.csv')

# %% [markdown]
# # Creating Models

# %%
 y = df_new.Outcome #just for the splitting sakes

# %% [markdown]
# Let's put the training set into tensorflow frame.

# %%
# Create an empty list that will eventually hold all created feature columns.
dataset_columns = ['Glucose', 'SkinThickness', 'Insulin', 'BMI', 'Age', 'DiabetesPedigreeFunction']
feature_columns = []

# Create numerical feature columns to represent all columns in dataset
for col in dataset_columns: 
    #Excluding outcome value, since outcome is still included in dataset
    col_tf = tf.feature_column.numeric_column(col)
    feature_columns.append(col_tf)

# Convert the list of feature columns into a layer that will later be fed into
# the model. 
feature_layer = layers.DenseFeatures(feature_columns)

# %% [markdown]
# Next, create the layers and fit the dataset into the model.

# %%
def create_model(learningRate, featureLayer, metrics):
  """Construct the model by passing dataset through regression & activation"""
  model = tf.keras.models.Sequential()

  # Add the feature layer that consists the columns/features of the dataset
  model.add(featureLayer)

  # Going through regression and then the sigmoid function for activation
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,),
                                  activation=tf.sigmoid),)

  # Optimise to get the best result, represented by the metrics
  # Use binary cross entropy loss due to binary classification case
  model.compile(optimizer=tf.keras.optimizers.Adam(lr=learningRate),                                                   
                loss=tf.keras.losses.BinaryCrossentropy(),
                metrics=metrics)

  return model        


def train_model(model, features, label, epochs, label_name,
                batch_size=None, shuffle=True):
  """Feed a dataset into the model in order to train it."""

  # Fit the data into the model
  history = model.fit(x=features, y=label, batch_size=batch_size,
                      epochs=epochs, shuffle=shuffle, verbose=1)

  return history

# %% [markdown]
# Now, let's fit the train set into the model. This time, dataset will be split by k-fold, in which there will be k pairs of train and test sets to model and evaluate.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.001
epochs = 700
batch_size = 10
label_name = "Outcome"
classification_threshold = 0.4

# Establish the metrics the model will measure.
METRICS = [
           tf.keras.metrics.BinaryAccuracy(name='accuracy', 
                                           threshold=classification_threshold),
           tf.keras.metrics.Precision(thresholds=classification_threshold,
                                 name='precision' 
                                 ),
           tf.keras.metrics.Recall(thresholds=classification_threshold,
                                 name='recall' 
                                 ),
          ]
train_acc = []
train_prec = []
train_rec = []

test_acc = []
test_prec = []
test_rec = []

# Train the model with K-Fold = 3
kf = KFold(3, random_state=2020, shuffle = True)
batch = 1
for train_idx, val_idx in kf.split(df_new, y):

    # Select the part of dataset to be train set-test set
    # according to indexes from K-Fold
    train_x = df_new.iloc[train_idx]
    train_y = y[train_idx].to_numpy()
    val_x = df_new.iloc[val_idx]
    val_y = y[val_idx].to_numpy()

    # Construct the model
    my_model = create_model(learning_rate, feature_layer, METRICS)

    # Converting train set into numpy formats
    train_features = {name:np.array(value) for name, value in train_x.items()}
    # Remove the label from the features
    train_label = train_y
    # Fit the data into the model
    history = train_model(my_model, train_features, train_label, 
                          epochs, label_name, batch_size)
    
    # Let's see the training result of this batch:
    train_res = my_model.evaluate(x=train_features, y=train_label, batch_size=batch_size)
    print("Train result:")
    print("Batch " + str(batch) +  " accuracy: " + "{:.00%}".format(train_res[1]))
    print("Batch " + str(batch) +  " precision: " + "{:.00%}".format(train_res[2]))
    print("Batch " + str(batch) +  " recall: " + "{:.00%}".format(train_res[3]))
        
    # Let's see how it goes with the test set for this batch:
    test_features = {name:np.array(value) for name, value in val_x.drop(['Outcome'], axis = 1).items()}
    test_label = val_y 
    test_res = my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)

    print("Test result:")
    print("Batch " + str(batch) +  " accuracy: " + "{:.00%}".format(test_res[1]))
    print("Batch " + str(batch) +  " precision: " + "{:.00%}".format(test_res[2]))
    print("Batch " + str(batch) +  " recall: " + "{:.00%}".format(test_res[3]))
    
    train_acc.append(train_res[1])
    train_prec.append(train_res[2])
    train_rec.append(train_res[3])

    test_acc.append(test_res[1])
    test_prec.append(test_res[2])
    test_rec.append(test_res[3])

    # # The list of epochs is stored separately from the rest of history.
    # epochs = history.epoch

    # # Isolate the classification metric for each epoch.
    # hist = pd.DataFrame(history.history)
    
    # plot_curve(epochs, hist, METRICS)
    batch += 1 

print("Averaged result: ")
print("Train result:")
print("Train accuracy: " + "{:.00%}".format(np.mean(train_acc)))
print("Train precision: " + "{:.00%}".format(np.mean(train_prec)))
print("Train recall: " + "{:.00%}".format(np.mean(train_rec)))
print("Test result:")
print("Test accuracy: " + "{:.00%}".format(np.mean(test_acc)))
print("Test precision: " + "{:.00%}".format(np.mean(test_prec)))
print("Test recall: " + "{:.00%}".format(np.mean(test_rec)))
# Out:
# Epoch 1/700
# 52/52 [==============================] - 0s 2ms/step - loss: 25.1907 - accuracy: 0.6582 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2/700
# 52/52 [==============================] - 0s 1ms/step - loss: 18.7637 - accuracy: 0.6582 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3/700
# 52/52 [==============================] - 0s 1ms/step - loss: 12.9269 - accuracy: 0.6504 - precision: 0.3750 - recall: 0.0343
# Epoch 4/700
# 52/52 [==============================] - 0s 1ms/step - loss: 8.3216 - accuracy: 0.6055 - precision: 0.3412 - recall: 0.1657
# Epoch 5/700
# 52/52 [==============================] - 0s 1ms/step - loss: 6.7084 - accuracy: 0.5742 - precision: 0.3648 - recall: 0.3314
# Epoch 6/700
# 52/52 [==============================] - 0s 2ms/step - loss: 6.3491 - accuracy: 0.5469 - precision: 0.3523 - recall: 0.3886
# Epoch 7/700
# 52/52 [==============================] - 0s 1ms/step - loss: 6.2133 - accuracy: 0.5430 - precision: 0.3575 - recall: 0.4229
# ...

# %%
print("Averaged result: ")
print("Train result:")
print("Train accuracy: " + "{:.00%}".format(np.mean(train_acc)))
print("Train precision: " + "{:.00%}".format(np.mean(train_prec)))
print("Train recall: " + "{:.00%}".format(np.mean(train_rec)))
print("Test result:")
print("Test accuracy: " + "{:.00%}".format(np.mean(test_acc)))
print("Test precision: " + "{:.00%}".format(np.mean(test_prec)))
print("Test recall: " + "{:.00%}".format(np.mean(test_rec)))
# Out:
# Averaged result:
# Train result:
# Train accuracy: 83%
# Train precision: 72%
# Train recall: 85%
# Test result:
# Test accuracy: 84%
# Test precision: 74%
# Test recall: 84%
